# %% [markdown]
# # NLP

# %%
from IPython.display import Image

# %%
# word2vec
# https://towardsdatascience.com/introduction-to-word-embedding-and-word2vec-652d0c2060fa
# https://shuzhanfan.github.io/2018/08/understanding-word2vec-and-doc2vec/
# use input(one word one hot encoding)*weights get a vector-cos similarity(a vector)
# input/output--one hot encoding(just one word in the architecture-multiple context words to train)
# embedding can be a pre trained library and is reuseable



# Continuous Bag-of-Words Model
# predicts the middle word based on surrounding context words
# CBOW is faster and has better representations for more frequent words.

# Continuous Skip-gram Model
# which predict words within a certain range before and after the current word in the same sentence
# more accurate with infrequent words

# %%
# doc2vec
# goal: finding similarity between sentences/paragraphs/documents

# %%
display(Image("/Users/weitianyi/Desktop/ML-Notes/DL-notes-pic/IMG_4189.jpeg", width = 800, height = 700))
